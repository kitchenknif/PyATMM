# %%
from sympy import *
init_printing()

# %%
kx, ky, kz = symbols('k_x, k_y, k_z')

# %%
kx + ky + kz
# Out:
# kₓ + k_y + k_z

# %%
w = Symbol('\omega')

# %%
w
# Out:
# \omega

# %%
e_xx, e_yy, e_zz, e_xy, e_yz, e_xz = symbols('\epsilon_{xx}, \epsilon_{yy}, \epsilon_{zz}, \epsilon_{xy}, \epsilon_{yz}, \epsilon_{xz}')

# %%
e_xx, e_yy, e_zz, e_xy, e_yz, e_xz
# Out:
# (\epsilon_{xx}, \epsilon_{yy}, \epsilon_{zz}, \epsilon_{xy}, \epsilon_{yz}, \e
# psilon_{xz})

# %%
M = Matrix([[w**2*e_xx -ky**2 - kz**2, w**2*e_xy + kx*ky, w**2*e_xz + kx*kz], 
           [w**2*e_xy + kx*ky, w**2*e_yy - kx**2 - kz**2, w**2*e_yz + ky*kz], 
           [w**2*e_xz + kx*kz, w**2*e_yz + kz*ky, w**2*e_zz -kx**2 - ky**2]])

# %%
M
# Out:
# ⎡                    2      2      2                        2
# ⎢\epsilon_{xx}⋅\omega  - k_y  - k_z     \epsilon_{xy}⋅\omega  + kₓ⋅k_y      \e
# ⎢
# ⎢                      2                                  2     2      2
# ⎢  \epsilon_{xy}⋅\omega  + kₓ⋅k_y     \epsilon_{yy}⋅\omega  - kₓ  - k_z    \ep
# ⎢
# ⎢                      2                                   2
# ⎣  \epsilon_{xz}⋅\omega  + kₓ⋅k_z      \epsilon_{yz}⋅\omega  + k_y⋅k_z    \eps
#
#                   2           ⎤
# psilon_{xz}⋅\omega  + kₓ⋅k_z  ⎥
#                               ⎥
#                  2            ⎥
# silon_{yz}⋅\omega  + k_y⋅k_z  ⎥
#                               ⎥
#                 2     2      2⎥
# ilon_{zz}⋅\omega  - kₓ  - k_y ⎦

# %%
A = factor(det(M), kz)

# %%
A
# Out:
#       2 ⎛                                                4
# \omega ⋅⎝\epsilon_{xx}⋅\epsilon_{yy}⋅\epsilon_{zz}⋅\omega  - \epsilon_{xx}⋅\ep
#
#                  2   2                                     2    2
# silon_{yy}⋅\omega ⋅kₓ  - \epsilon_{xx}⋅\epsilon_{yy}⋅\omega ⋅k_y  - \epsilon_{
#
#                  2       4                                     2   2
# xx}⋅\epsilon_{yz} ⋅\omega  - \epsilon_{xx}⋅\epsilon_{zz}⋅\omega ⋅kₓ  + \epsilo
#
#          4                   2    2                2                     4
# n_{xx}⋅kₓ  + \epsilon_{xx}⋅kₓ ⋅k_y  - \epsilon_{xy} ⋅\epsilon_{zz}⋅\omega  + \
#
#             2       2   2                2       2    2
# epsilon_{xy} ⋅\omega ⋅kₓ  + \epsilon_{xy} ⋅\omega ⋅k_y  + 2⋅\epsilon_{xy}⋅\eps
#
#                               4                                       2
# ilon_{xz}⋅\epsilon_{yz}⋅\omega  - 2⋅\epsilon_{xy}⋅\epsilon_{zz}⋅\omega ⋅kₓ⋅k_y
#
#                      3                             3                2
#  + 2⋅\epsilon_{xy}⋅kₓ ⋅k_y + 2⋅\epsilon_{xy}⋅kₓ⋅k_y  - \epsilon_{xz} ⋅\epsilon
#
#             4                2       2   2
# _{yy}⋅\omega  + \epsilon_{xz} ⋅\omega ⋅kₓ  + 2⋅\epsilon_{xz}⋅\epsilon_{yz}⋅\om
#
#    2                                            2    2                   2
# ega ⋅kₓ⋅k_y - \epsilon_{yy}⋅\epsilon_{zz}⋅\omega ⋅k_y  + \epsilon_{yy}⋅kₓ ⋅k_y
#
# 2                    4                2       2    2                    4
#   + \epsilon_{yy}⋅k_y  + \epsilon_{yz} ⋅\omega ⋅k_y  + \epsilon_{zz}⋅k_z  + k_
#
#  3                                                 2 ⎛
# z ⋅(2⋅\epsilon_{xz}⋅kₓ + 2⋅\epsilon_{yz}⋅k_y) + k_z ⋅⎝- \epsilon_{xx}⋅\epsilon
#
#             2                   2                                         2
# _{zz}⋅\omega  + \epsilon_{xx}⋅kₓ  + 2⋅\epsilon_{xy}⋅kₓ⋅k_y + \epsilon_{xz} ⋅\o
#
#     2                                     2                    2
# mega  - \epsilon_{yy}⋅\epsilon_{zz}⋅\omega  + \epsilon_{yy}⋅k_y  + \epsilon_{y
#
#   2       2                   2                    2⎞       ⎛
# z} ⋅\omega  + \epsilon_{zz}⋅kₓ  + \epsilon_{zz}⋅k_y ⎠ + k_z⋅⎝- 2⋅\epsilon_{xx}
#
#                      2                                           2
# ⋅\epsilon_{yz}⋅\omega ⋅k_y + 2⋅\epsilon_{xy}⋅\epsilon_{xz}⋅\omega ⋅k_y + 2⋅\ep
#
#                                2                                          2
# silon_{xy}⋅\epsilon_{yz}⋅\omega ⋅kₓ - 2⋅\epsilon_{xz}⋅\epsilon_{yy}⋅\omega ⋅kₓ
#
#                      3                         2                     2
#  + 2⋅\epsilon_{xz}⋅kₓ  + 2⋅\epsilon_{xz}⋅kₓ⋅k_y  + 2⋅\epsilon_{yz}⋅kₓ ⋅k_y + 2
#
#                   3⎞⎞
# ⋅\epsilon_{yz}⋅k_y ⎠⎠

# %%
M.rref()
# Out:
# ⎛⎡1  0  0⎤, [0, 1, 2]⎞
# ⎜⎢       ⎥           ⎟
# ⎜⎢0  1  0⎥           ⎟
# ⎜⎢       ⎥           ⎟
# ⎝⎣0  0  1⎦           ⎠

# %%
M.nullspace()
# Out:
# []

# %%
solve(Eq(A, 0), kz)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c1f79c86674f> in <module>()
# ----> 1 solve(Eq(A, 0), kz)
#
# C:\Programs\Python34\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#     907     ###########################################################################
#     908     if bare_f:
# --> 909         solution = _solve(f[0], *symbols, **flags)
#     910     else:
#     911         solution = _solve_system(f, symbols, **flags)
#
# C:\Programs\Python34\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1154         dens = denoms(f, symbols)
#    1155         for m in f.args:
# -> 1156             soln = _solve(m, symbol, **flags)
#    1157             result.update(set(soln))
#    1158         result = list(result)
#
# C:\Programs\Python34\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1427                     for den in dens)]
#    1428         # keep only results if the check is not False
# -> 1429         result = [r for r in result if isinstance(r, RootOf) or
#    1430                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1431     return result
#
# C:\Programs\Python34\lib\site-packages\sympy\solvers\solvers.py in <listcomp>(.0)
#    1428         # keep only results if the check is not False
#    1429         result = [r for r in result if isinstance(r, RootOf) or
# -> 1430                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1431     return result
#    1432
#
# C:\Programs\Python34\lib\site-packages\sympy\solvers\solvers.py in checksol(f, symbol, sol, **flags)
#     215                 # there are free symbols -- simple expansion might work
#     216                 _, val = val.as_content_primitive()
# --> 217                 val = expand_mul(expand_multinomial(val))
#     218         elif attempt == 2:
#     219             if minimal:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\function.py in expand_mul(expr, deep)
#    1986     """
#    1987     return sympify(expr).expand(deep=deep, mul=True, power_exp=False,
# -> 1988     power_base=False, basic=False, multinomial=False, log=False)
#    1989
#    1990
#
# C:\Programs\Python34\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      91             def wrapper(*args, **kwargs):
#      92                 try:
# ---> 93                     retval = cfunc(*args, **kwargs)
#      94                 except TypeError:
#      95                     retval = func(*args, **kwargs)
#
# C:\Programs\Python34\lib\functools.py in wrapper(*args, **kwds)
#     470                         hits += 1
#     471                         return result
# --> 472                 result = user_function(*args, **kwds)
#     473                 with lock:
#     474                     if key in cache:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    2869             if use_hint:
#    2870                 hint = '_eval_expand_' + hint
# -> 2871                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    2872
#    2873         while True:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    2810
#    2811         if hasattr(expr, hint):
# -> 2812             newexpr = getattr(expr, hint)(**hints)
#    2813             if newexpr != expr:
#    2814                 return (newexpr, True)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\mul.py in _eval_expand_mul(self, **hints)
#     755         if d.is_Mul:
#     756             n, d = [i._eval_expand_mul(**hints) if i.is_Mul else i
# --> 757                 for i in (n, d)]
#     758             expr = n/d
#     759             if not expr.is_Mul:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\mul.py in <listcomp>(.0)
#     755         if d.is_Mul:
#     756             n, d = [i._eval_expand_mul(**hints) if i.is_Mul else i
# --> 757                 for i in (n, d)]
#     758             expr = n/d
#     759             if not expr.is_Mul:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\mul.py in _eval_expand_mul(self, **hints)
#     776             plain = self.func(*plain)
#     777             if sums:
# --> 778                 terms = self.func._expandsums(sums)
#     779                 args = []
#     780                 for term in terms:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\mul.py in _expandsums(sums)
#     742         right = Mul._expandsums(sums[L//2:])
#     743
# --> 744         terms = [Mul(a, b) for a in left for b in right]
#     745         added = Add(*terms)
#     746         return Add.make_args(added)  # it may have collapsed down to one term
#
# C:\Programs\Python34\lib\site-packages\sympy\core\mul.py in <listcomp>(.0)
#     742         right = Mul._expandsums(sums[L//2:])
#     743
# --> 744         terms = [Mul(a, b) for a in left for b in right]
#     745         added = Add(*terms)
#     746         return Add.make_args(added)  # it may have collapsed down to one term
#
# C:\Programs\Python34\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      91             def wrapper(*args, **kwargs):
#      92                 try:
# ---> 93                     retval = cfunc(*args, **kwargs)
#      94                 except TypeError:
#      95                     retval = func(*args, **kwargs)
#
# C:\Programs\Python34\lib\functools.py in wrapper(*args, **kwds)
#     470                         hits += 1
#     471                         return result
# --> 472                 result = user_function(*args, **kwds)
#     473                 with lock:
#     474                     if key in cache:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\operations.py in __new__(cls, *args, **options)
#      39             return args[0]
#      40
# ---> 41         c_part, nc_part, order_symbols = cls.flatten(args)
#      42         is_commutative = not nc_part
#      43         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# C:\Programs\Python34\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     181                 a, b = b, a
#     182             assert not a is S.One
# --> 183             if not a.is_zero and a.is_Rational:
#     184                 r, b = b.as_coeff_Mul()
#     185                 if b.is_Add:
#
# C:\Programs\Python34\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     215     def getit(self):
#     216         try:
# --> 217             return self._assumptions[fact]
#     218         except KeyError:
#     219             if self._assumptions is self.default_assumptions:
#
# KeyboardInterrupt:
