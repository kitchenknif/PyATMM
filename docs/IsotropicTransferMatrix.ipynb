# %%
from sympy import *
import numpy as np
init_printing()

# %% [markdown]
# Define symbols
# ----
#
# Primary
# --

# %%
eps = Symbol('\epsilon')
k_x, k_y, k_z = symbols('k_x, k_y, k_z')
w, c_0, c, d = symbols('\omega, c_0, c, d')

# %%
eps, k_x, k_y, w, c_0, c, d
# Out:
# (\epsilon, kₓ, k_y, \omega, c₀, c, d)

# %% [markdown]
# Secondary
# --

# %%
p_1, p_2, p_3, p_4 = symbols('p_1, p_2, p_3, p_4')
k_z_1, k_z_2, k_z_3, k_z_4 = symbols('k_z1, k_z2, k_z3, k_z4')
mod_k_z = Symbol('k_z')
k_1, k_2, k_3, k_4 = symbols('k_1, k_2, k_3, k_4')
c = c_0 / sqrt(eps)

# %% [markdown]
# Eigenmodes
# ---

# %%
mod_k_z = sqrt(c/w - k_y**2 - k_x**2)

k_z_1 = mod_k_z
k_z_2 = -mod_k_z
k_z_3 = mod_k_z
k_z_4 = -mod_k_z

k_1 = Matrix([k_x, k_y, k_z_1])
k_2 = Matrix([k_x, k_y, k_z_2])
k_3 = Matrix([k_x, k_y, k_z_3])
k_4 = Matrix([k_x, k_y, k_z_4])

p_1 = Matrix([cos(k_x/k_z_1), 0, sin(k_x/k_z_1)])
p_2 = Matrix([cos(k_x/k_z_2), 0, sin(k_x/k_z_2)])
p_3 = Matrix([0, -cos(k_y/k_z_3), sin(k_y/k_z_3)])
p_4 = Matrix([0, cos(k_y/k_z_4), sin(k_y/k_z_4)])

# Norm
p_1 = simplify(p_1 / p_1.dot(p_1))
p_2 = simplify(p_2 / p_2.dot(p_2))
p_3 = simplify(p_3 / p_3.dot(p_3))
p_4 = simplify(p_4 / p_4.dot(p_4))

q_1 = simplify((c/w) * k_1.cross(p_1))
q_2 = simplify((c/w) * k_2.cross(p_2))
q_3 = simplify((c/w) * k_3.cross(p_3))
q_4 = simplify((c/w) * k_4.cross(p_4))

# %%
k_1, k_2, k_3, k_4
# Out:
# ⎛⎡            kₓ             ⎤, ⎡             kₓ             ⎤, ⎡            k
# ⎜⎢                           ⎥  ⎢                            ⎥  ⎢
# ⎜⎢            k_y            ⎥  ⎢            k_y             ⎥  ⎢            k
# ⎜⎢                           ⎥  ⎢                            ⎥  ⎢
# ⎜⎢    _______________________⎥  ⎢     _______________________⎥  ⎢    _________
# ⎜⎢   ╱     2      2     c    ⎥  ⎢    ╱     2      2     c    ⎥  ⎢   ╱     2
# ⎜⎢  ╱  - kₓ  - k_y  + ────── ⎥  ⎢-  ╱  - kₓ  - k_y  + ────── ⎥  ⎢  ╱  - kₓ  -
# ⎝⎣╲╱                  \omega ⎦  ⎣ ╲╱                  \omega ⎦  ⎣╲╱
#
# ₓ             ⎤, ⎡             kₓ             ⎤⎞
#               ⎥  ⎢                            ⎥⎟
# _y            ⎥  ⎢            k_y             ⎥⎟
#               ⎥  ⎢                            ⎥⎟
# ______________⎥  ⎢     _______________________⎥⎟
#    2     c    ⎥  ⎢    ╱     2      2     c    ⎥⎟
# k_y  + ────── ⎥  ⎢-  ╱  - kₓ  - k_y  + ────── ⎥⎟
#        \omega ⎦  ⎣ ╲╱                  \omega ⎦⎠

# %%
p_1, p_2, p_3, p_4
# Out:
# ⎛⎡   ⎛             kₓ            ⎞⎤  ⎡   ⎛             kₓ            ⎞ ⎤
# ⎜⎢   ⎜───────────────────────────⎟⎥, ⎢   ⎜───────────────────────────⎟ ⎥, ⎡
# ⎜⎢   ⎜    _______________________⎟⎥  ⎢   ⎜    _______________________⎟ ⎥  ⎢
# ⎜⎢cos⎜   ╱     2      2     c    ⎟⎥  ⎢cos⎜   ╱     2      2     c    ⎟ ⎥  ⎢
# ⎜⎢   ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎥  ⎢   ⎜  ╱  - kₓ  - k_y  + ────── ⎟ ⎥  ⎢-
# ⎜⎢   ⎝╲╱                  \omega ⎠⎥  ⎢   ⎝╲╱                  \omega ⎠ ⎥  ⎢
# ⎜⎢                                ⎥  ⎢                                 ⎥  ⎢ co
# ⎜⎢               0                ⎥  ⎢                0                ⎥  ⎢
# ⎜⎢                                ⎥  ⎢                                 ⎥  ⎢
# ⎜⎢   ⎛             kₓ            ⎞⎥  ⎢    ⎛             kₓ            ⎞⎥  ⎢
# ⎜⎢   ⎜───────────────────────────⎟⎥  ⎢-   ⎜───────────────────────────⎟⎥  ⎢
# ⎜⎢   ⎜    _______________________⎟⎥  ⎢    ⎜    _______________________⎟⎥  ⎢
# ⎜⎢sin⎜   ╱     2      2     c    ⎟⎥  ⎢ sin⎜   ╱     2      2     c    ⎟⎥  ⎢
# ⎜⎢   ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎥  ⎢    ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎥  ⎢sin
# ⎜⎣   ⎝╲╱                  \omega ⎠⎦  ⎣    ⎝╲╱                  \omega ⎠⎦  ⎢
# ⎝                                                                         ⎣
#
#                                                                     ⎞
#              0                ⎤, ⎡                0                ⎤⎟
#                               ⎥  ⎢                                 ⎥⎟
#  ⎛            k_y            ⎞⎥  ⎢   ⎛            k_y            ⎞ ⎥⎟
#  ⎜───────────────────────────⎟⎥  ⎢   ⎜───────────────────────────⎟ ⎥⎟
#  ⎜    _______________________⎟⎥  ⎢   ⎜    _______________________⎟ ⎥⎟
# s⎜   ╱     2      2     c    ⎟⎥  ⎢cos⎜   ╱     2      2     c    ⎟ ⎥⎟
#  ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎥  ⎢   ⎜  ╱  - kₓ  - k_y  + ────── ⎟ ⎥⎟
#  ⎝╲╱                  \omega ⎠⎥  ⎢   ⎝╲╱                  \omega ⎠ ⎥⎟
#                               ⎥  ⎢                                 ⎥⎟
# ⎛            k_y            ⎞ ⎥  ⎢    ⎛            k_y            ⎞⎥⎟
# ⎜───────────────────────────⎟ ⎥  ⎢-   ⎜───────────────────────────⎟⎥⎟
# ⎜    _______________________⎟ ⎥  ⎢    ⎜    _______________________⎟⎥⎟
# ⎜   ╱     2      2     c    ⎟ ⎥  ⎢ sin⎜   ╱     2      2     c    ⎟⎥⎟
# ⎜  ╱  - kₓ  - k_y  + ────── ⎟ ⎥  ⎢    ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎥⎟
# ⎝╲╱                  \omega ⎠ ⎦  ⎣    ⎝╲╱                  \omega ⎠⎦⎠

# %%
q_1, q_2, q_3, q_4
# Out:
# ⎛
# ⎜⎡                                          ⎛             kₓ            ⎞
# ⎜⎢                                 c⋅k_y⋅   ⎜───────────────────────────⎟
# ⎜⎢                                          ⎜    _______________________⎟
# ⎜⎢                                       sin⎜   ╱     2      2     c    ⎟
# ⎜⎢                                          ⎜  ╱  - kₓ  - k_y  + ────── ⎟
# ⎜⎢                                          ⎝╲╱                  \omega ⎠
# ⎜⎢                                 ──────────────────────────────────────
# ⎜⎢                                                 \omega
# ⎜⎢
# ⎜⎢  ⎛                                            _______________________
# ⎜⎢  ⎜        ⎛             kₓ            ⎞      ╱     2      2     c        ⎛
# ⎜⎢c⋅⎜- kₓ⋅   ⎜───────────────────────────⎟ +   ╱  - kₓ  - k_y  + ────── ⋅   ⎜─
# ⎜⎢  ⎜        ⎜    _______________________⎟   ╲╱                  \omega     ⎜
# ⎜⎢  ⎜     sin⎜   ╱     2      2     c    ⎟                               cos⎜
# ⎜⎢  ⎜        ⎜  ╱  - kₓ  - k_y  + ────── ⎟                                  ⎜
# ⎜⎢  ⎝        ⎝╲╱                  \omega ⎠                                  ⎝╲
# ⎜⎢────────────────────────────────────────────────────────────────────────────
# ⎜⎢                                                 \omega
# ⎜⎢
# ⎜⎢                                          ⎛             kₓ            ⎞
# ⎜⎢                                -c⋅k_y⋅   ⎜───────────────────────────⎟
# ⎜⎢                                          ⎜    _______________________⎟
# ⎜⎢                                       cos⎜   ╱     2      2     c    ⎟
# ⎜⎢                                          ⎜  ╱  - kₓ  - k_y  + ────── ⎟
# ⎜⎢                                          ⎝╲╱                  \omega ⎠
# ⎜⎢                                ────────────────────────────────────────
# ⎝⎣                                                 \omega
#
#
#                             ⎤  ⎡                                         ⎛
#                             ⎥  ⎢                               -c⋅k_y⋅   ⎜────
#                             ⎥  ⎢                                         ⎜
#                             ⎥  ⎢                                      sin⎜   ╱
#                             ⎥  ⎢                                         ⎜  ╱
#                             ⎥  ⎢                                         ⎝╲╱
#                             ⎥, ⎢                               ───────────────
#                             ⎥  ⎢
#                             ⎥  ⎢
#                            ⎞⎥  ⎢  ⎛                                          _
#             kₓ            ⎞⎟⎥  ⎢  ⎜      ⎛             kₓ            ⎞      ╱
# ──────────────────────────⎟⎟⎥  ⎢c⋅⎜kₓ⋅   ⎜───────────────────────────⎟ -   ╱
#    _______________________⎟⎟⎥  ⎢  ⎜      ⎜    _______________________⎟   ╲╱
#   ╱     2      2     c    ⎟⎟⎥  ⎢  ⎜   sin⎜   ╱     2      2     c    ⎟
#  ╱  - kₓ  - k_y  + ────── ⎟⎟⎥  ⎢  ⎜      ⎜  ╱  - kₓ  - k_y  + ────── ⎟
# ╱                  \omega ⎠⎠⎥  ⎢  ⎝      ⎝╲╱                  \omega ⎠
# ────────────────────────────⎥  ⎢──────────────────────────────────────────────
#                             ⎥  ⎢
#                             ⎥  ⎢
#                             ⎥  ⎢                                         ⎛
#                             ⎥  ⎢                               -c⋅k_y⋅   ⎜────
#                             ⎥  ⎢                                         ⎜
#                             ⎥  ⎢                                      cos⎜   ╱
#                             ⎥  ⎢                                         ⎜  ╱
#                             ⎥  ⎢                                         ⎝╲╱
#                             ⎥  ⎢                               ───────────────
#                             ⎦  ⎣
#
#                                                            ⎡  ⎛
#          kₓ            ⎞                                ⎤  ⎢  ⎜       ⎛
# ───────────────────────⎟                                ⎥  ⎢c⋅⎜k_y⋅   ⎜───────
# _______________________⎟                                ⎥  ⎢  ⎜       ⎜    ___
#      2      2     c    ⎟                                ⎥  ⎢  ⎜    sin⎜   ╱
#  - kₓ  - k_y  + ────── ⎟                                ⎥  ⎢  ⎜       ⎜  ╱  -
#                 \omega ⎠                                ⎥  ⎢  ⎝       ⎝╲╱
# ─────────────────────────                               ⎥, ⎢──────────────────
#   \omega                                                ⎥  ⎢
#                                                         ⎥  ⎢
# ______________________                                 ⎞⎥  ⎢
#     2      2     c        ⎛             kₓ            ⎞⎟⎥  ⎢
# - kₓ  - k_y  + ────── ⋅   ⎜───────────────────────────⎟⎟⎥  ⎢
#                \omega     ⎜    _______________________⎟⎟⎥  ⎢
#                        cos⎜   ╱     2      2     c    ⎟⎟⎥  ⎢
#                           ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎟⎥  ⎢
#                           ⎝╲╱                  \omega ⎠⎠⎥  ⎢
# ────────────────────────────────────────────────────────⎥  ⎢
#   \omega                                                ⎥  ⎢
#                                                         ⎥  ⎢
#          kₓ            ⎞                                ⎥  ⎢
# ───────────────────────⎟                                ⎥  ⎢
# _______________________⎟                                ⎥  ⎢
#      2      2     c    ⎟                                ⎥  ⎢
#  - kₓ  - k_y  + ────── ⎟                                ⎥  ⎢
#                 \omega ⎠                                ⎥  ⎢
# ─────────────────────────                               ⎥  ⎣
#   \omega                                                ⎦
#
#                             _______________________
#      k_y            ⎞      ╱     2      2     c        ⎛            k_y
# ────────────────────⎟ +   ╱  - kₓ  - k_y  + ────── ⋅   ⎜──────────────────────
# ____________________⎟   ╲╱                  \omega     ⎜    __________________
#   2      2     c    ⎟                               cos⎜   ╱     2      2
# kₓ  - k_y  + ────── ⎟                                  ⎜  ╱  - kₓ  - k_y  + ──
#              \omega ⎠                                  ⎝╲╱                  \o
# ──────────────────────────────────────────────────────────────────────────────
#                                \omega
#
#                        ⎛            k_y            ⎞
#               -c⋅kₓ⋅   ⎜───────────────────────────⎟
#                        ⎜    _______________________⎟
#                     sin⎜   ╱     2      2     c    ⎟
#                        ⎜  ╱  - kₓ  - k_y  + ────── ⎟
#                        ⎝╲╱                  \omega ⎠
#               ───────────────────────────────────────
#                                \omega
#
#                        ⎛            k_y            ⎞
#               -c⋅kₓ⋅   ⎜───────────────────────────⎟
#                        ⎜    _______________________⎟
#                     cos⎜   ╱     2      2     c    ⎟
#                        ⎜  ╱  - kₓ  - k_y  + ────── ⎟
#                        ⎝╲╱                  \omega ⎠
#               ───────────────────────────────────────
#                                \omega
#
#
#       ⎞⎤  ⎡  ⎛                                             ___________________
#      ⎞⎟⎥  ⎢  ⎜         ⎛            k_y            ⎞      ╱     2      2     c
# ─────⎟⎟⎥  ⎢c⋅⎜- k_y⋅   ⎜───────────────────────────⎟ +   ╱  - kₓ  - k_y  + ───
# _____⎟⎟⎥  ⎢  ⎜         ⎜    _______________________⎟   ╲╱                  \om
# c    ⎟⎟⎥  ⎢  ⎜      sin⎜   ╱     2      2     c    ⎟
# ──── ⎟⎟⎥  ⎢  ⎜         ⎜  ╱  - kₓ  - k_y  + ────── ⎟
# mega ⎠⎠⎥  ⎢  ⎝         ⎝╲╱                  \omega ⎠
# ───────⎥, ⎢───────────────────────────────────────────────────────────────────
#        ⎥  ⎢                                                  \omega
#        ⎥  ⎢
#        ⎥  ⎢                                          ⎛            k_y
#        ⎥  ⎢                                  c⋅kₓ⋅   ⎜────────────────────────
#        ⎥  ⎢                                          ⎜    ____________________
#        ⎥  ⎢                                       sin⎜   ╱     2      2     c
#        ⎥  ⎢                                          ⎜  ╱  - kₓ  - k_y  + ────
#        ⎥  ⎢                                          ⎝╲╱                  \ome
#        ⎥  ⎢                                  ─────────────────────────────────
#        ⎥  ⎢                                                  \omega
#        ⎥  ⎢
#        ⎥  ⎢                                          ⎛            k_y
#        ⎥  ⎢                                  c⋅kₓ⋅   ⎜────────────────────────
#        ⎥  ⎢                                          ⎜    ____________________
#        ⎥  ⎢                                       cos⎜   ╱     2      2     c
#        ⎥  ⎢                                          ⎜  ╱  - kₓ  - k_y  + ────
#        ⎥  ⎢                                          ⎝╲╱                  \ome
#        ⎥  ⎢                                  ─────────────────────────────────
#        ⎦  ⎣                                                  \omega
#
#
# ____                                 ⎞⎤⎞
#         ⎛            k_y            ⎞⎟⎥⎟
# ─── ⋅   ⎜───────────────────────────⎟⎟⎥⎟
# ega     ⎜    _______________________⎟⎟⎥⎟
#      cos⎜   ╱     2      2     c    ⎟⎟⎥⎟
#         ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎟⎥⎟
#         ⎝╲╱                  \omega ⎠⎠⎥⎟
# ──────────────────────────────────────⎥⎟
#                                       ⎥⎟
#                                       ⎥⎟
#    ⎞                                  ⎥⎟
# ───⎟                                  ⎥⎟
# ___⎟                                  ⎥⎟
#    ⎟                                  ⎥⎟
# ── ⎟                                  ⎥⎟
# ga ⎠                                  ⎥⎟
# ────                                  ⎥⎟
#                                       ⎥⎟
#                                       ⎥⎟
#    ⎞                                  ⎥⎟
# ───⎟                                  ⎥⎟
# ___⎟                                  ⎥⎟
#    ⎟                                  ⎥⎟
# ── ⎟                                  ⎥⎟
# ga ⎠                                  ⎥⎟
# ────                                  ⎥⎟
#                                       ⎦⎟
#                                        ⎠

# %%
D = Matrix([[p_1[0], p_2[0], p_3[0], p_4[0]], 
            [q_1[1], q_2[1], q_3[1], q_4[1]], 
            [p_1[1], p_2[1], p_3[1], p_4[1]], 
            [q_1[0], q_2[0], q_3[0], q_4[0]]])
D
# Out:
# ⎡                                       ⎛             kₓ            ⎞
# ⎢                                       ⎜───────────────────────────⎟
# ⎢                                       ⎜    _______________________⎟
# ⎢                                    cos⎜   ╱     2      2     c    ⎟
# ⎢                                       ⎜  ╱  - kₓ  - k_y  + ────── ⎟
# ⎢                                       ⎝╲╱                  \omega ⎠
# ⎢
# ⎢  ⎛                                            _______________________
# ⎢  ⎜        ⎛             kₓ            ⎞      ╱     2      2     c        ⎛
# ⎢c⋅⎜- kₓ⋅   ⎜───────────────────────────⎟ +   ╱  - kₓ  - k_y  + ────── ⋅   ⎜──
# ⎢  ⎜        ⎜    _______________________⎟   ╲╱                  \omega     ⎜
# ⎢  ⎜     sin⎜   ╱     2      2     c    ⎟                               cos⎜
# ⎢  ⎜        ⎜  ╱  - kₓ  - k_y  + ────── ⎟                                  ⎜
# ⎢  ⎝        ⎝╲╱                  \omega ⎠                                  ⎝╲╱
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                                 \omega
# ⎢
# ⎢
# ⎢                                                   0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                          ⎛             kₓ            ⎞
# ⎢                                 c⋅k_y⋅   ⎜───────────────────────────⎟
# ⎢                                          ⎜    _______________________⎟
# ⎢                                       sin⎜   ╱     2      2     c    ⎟
# ⎢                                          ⎜  ╱  - kₓ  - k_y  + ────── ⎟
# ⎢                                          ⎝╲╱                  \omega ⎠
# ⎢                                 ──────────────────────────────────────
# ⎣                                                 \omega
#
#                                                                    ⎛
#                                                                    ⎜──────────
#                                                                    ⎜    ______
#                                                                 cos⎜   ╱     2
#                                                                    ⎜  ╱  - kₓ
#                                                                    ⎝╲╱
#
#                           ⎞    ⎛                                          ____
#            kₓ            ⎞⎟    ⎜      ⎛             kₓ            ⎞      ╱
# ─────────────────────────⎟⎟  c⋅⎜kₓ⋅   ⎜───────────────────────────⎟ -   ╱  - k
#   _______________________⎟⎟    ⎜      ⎜    _______________________⎟   ╲╱
#  ╱     2      2     c    ⎟⎟    ⎜   sin⎜   ╱     2      2     c    ⎟
# ╱  - kₓ  - k_y  + ────── ⎟⎟    ⎜      ⎜  ╱  - kₓ  - k_y  + ────── ⎟
#                   \omega ⎠⎠    ⎝      ⎝╲╱                  \omega ⎠
# ───────────────────────────  ─────────────────────────────────────────────────
#                                                                              \
#
#
#
#
#
#
#
#
#
#                                                                       ⎛
#                                                             -c⋅k_y⋅   ⎜───────
#                                                                       ⎜    ___
#                                                                    sin⎜   ╱
#                                                                       ⎜  ╱  -
#                                                                       ⎝╲╱
#                                                             ──────────────────
#                                                                              \
#
#    kₓ            ⎞
# ─────────────────⎟
# _________________⎟
#       2     c    ⎟
#  - k_y  + ────── ⎟
#           \omega ⎠
#
# ___________________                                 ⎞
#  2      2     c        ⎛             kₓ            ⎞⎟
# ₓ  - k_y  + ────── ⋅   ⎜───────────────────────────⎟⎟
#             \omega     ⎜    _______________________⎟⎟
#                     cos⎜   ╱     2      2     c    ⎟⎟
#                        ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎟
#                        ⎝╲╱                  \omega ⎠⎠
# ─────────────────────────────────────────────────────
# omega
#
#
#  0
#
#
#
#
#
#                                                          ⎛
#       kₓ            ⎞                                    ⎜       ⎛
# ────────────────────⎟                                  c⋅⎜k_y⋅   ⎜────────────
# ____________________⎟                                    ⎜       ⎜    ________
#   2      2     c    ⎟                                    ⎜    sin⎜   ╱     2
# kₓ  - k_y  + ────── ⎟                                    ⎜       ⎜  ╱  - kₓ  -
#              \omega ⎠                                    ⎝       ⎝╲╱
# ──────────────────────                                 ───────────────────────
# omega
#
#
#                             0
#
#
#
#
#
#
#                   ⎛            k_y            ⎞
#          -c⋅kₓ⋅   ⎜───────────────────────────⎟
#                   ⎜    _______________________⎟
#                sin⎜   ╱     2      2     c    ⎟
#                   ⎜  ╱  - kₓ  - k_y  + ────── ⎟
#                   ⎝╲╱                  \omega ⎠
#          ───────────────────────────────────────
#                           \omega
#
#                 ⎛            k_y            ⎞
#             -   ⎜───────────────────────────⎟
#                 ⎜    _______________________⎟
#              cos⎜   ╱     2      2     c    ⎟
#                 ⎜  ╱  - kₓ  - k_y  + ────── ⎟
#                 ⎝╲╱                  \omega ⎠
#
#                        _______________________
# k_y            ⎞      ╱     2      2     c        ⎛            k_y
# ───────────────⎟ +   ╱  - kₓ  - k_y  + ────── ⋅   ⎜───────────────────────────
# _______________⎟   ╲╱                  \omega     ⎜    _______________________
#     2     c    ⎟                               cos⎜   ╱     2      2     c
#  k_y  + ────── ⎟                                  ⎜  ╱  - kₓ  - k_y  + ──────
#         \omega ⎠                                  ⎝╲╱                  \omega
# ──────────────────────────────────────────────────────────────────────────────
#                           \omega
#
#
#                                                         0
#
#
#
#
#
#
#                                               ⎛            k_y            ⎞
#                                       c⋅kₓ⋅   ⎜───────────────────────────⎟
#                                               ⎜    _______________________⎟
#                                            sin⎜   ╱     2      2     c    ⎟
#                                               ⎜  ╱  - kₓ  - k_y  + ────── ⎟
#                                               ⎝╲╱                  \omega ⎠
#                                       ─────────────────────────────────────
#                                                       \omega
#
#                                            ⎛            k_y            ⎞
#                                            ⎜───────────────────────────⎟
#                                            ⎜    _______________________⎟
#                                         cos⎜   ╱     2      2     c    ⎟
#                                            ⎜  ╱  - kₓ  - k_y  + ────── ⎟
#                                            ⎝╲╱                  \omega ⎠
#
#  ⎞    ⎛                                             _______________________
# ⎞⎟    ⎜         ⎛            k_y            ⎞      ╱     2      2     c
# ⎟⎟  c⋅⎜- k_y⋅   ⎜───────────────────────────⎟ +   ╱  - kₓ  - k_y  + ────── ⋅
# ⎟⎟    ⎜         ⎜    _______________________⎟   ╲╱                  \omega
# ⎟⎟    ⎜      sin⎜   ╱     2      2     c    ⎟                               co
# ⎟⎟    ⎜         ⎜  ╱  - kₓ  - k_y  + ────── ⎟
# ⎠⎠    ⎝         ⎝╲╱                  \omega ⎠
# ──  ──────────────────────────────────────────────────────────────────────────
#                                                       \omega
#
#                                ⎤
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                               ⎞⎥
#  ⎛            k_y            ⎞⎟⎥
#  ⎜───────────────────────────⎟⎟⎥
#  ⎜    _______________________⎟⎟⎥
# s⎜   ╱     2      2     c    ⎟⎟⎥
#  ⎜  ╱  - kₓ  - k_y  + ────── ⎟⎟⎥
#  ⎝╲╱                  \omega ⎠⎠⎥
# ───────────────────────────────⎥
#                                ⎦

# %%
P = Matrix([[exp(-I*k_z_1*d), 0, 0, 0],
            [0, exp(-I*k_z_2*d), 0, 0],
            [0, 0, exp(-I*k_z_3*d), 0],
            [0, 0, 0, exp(-I*k_z_4*d)]])
P
# Out:
# ⎡           ____________________________________
# ⎢          ╱     2      2            c₀
# ⎢ -ⅈ⋅d⋅   ╱  - kₓ  - k_y  + ───────────────────
# ⎢        ╱                    __________
# ⎢      ╲╱                   ╲╱ \epsilon ⋅\omega
# ⎢ℯ                                                                      0
# ⎢
# ⎢                                                           __________________
# ⎢                                                          ╱     2      2
# ⎢                                                  ⅈ⋅d⋅   ╱  - kₓ  - k_y  + ──
# ⎢                                                        ╱
# ⎢                                                      ╲╱                   ╲╱
# ⎢                       0                         ℯ
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                       0                                               0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣                       0                                               0
#
#
#
#
#
#
#                                            0
#
# __________________
#        c₀
# ─────────────────
# __________
#  \epsilon ⋅\omega
#                                            0
#
#                                ____________________________________
#                               ╱     2      2            c₀
#                      -ⅈ⋅d⋅   ╱  - kₓ  - k_y  + ───────────────────
#                             ╱                    __________
#                           ╲╱                   ╲╱ \epsilon ⋅\omega
#                     ℯ
#
#
#
#                                                                       ⅈ⋅d⋅   ╱
#                                                                             ╱
#                                                                           ╲╱
#                                            0                         ℯ
#
#                                      ⎤
#                                      ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#              0                       ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#              0                       ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#                                      ⎥
#              0                       ⎥
#                                      ⎥
#  ____________________________________⎥
# ╱     2      2            c₀         ⎥
#   - kₓ  - k_y  + ─────────────────── ⎥
#                    __________        ⎥
#                  ╲╱ \epsilon ⋅\omega ⎥
#                                      ⎦

# %%
D.subs({k_x:0, k_y:0})
# Out:
# ⎡      1                1                0               0       ⎤
# ⎢                                                                ⎥
# ⎢      ________         ________                                 ⎥
# ⎢     ╱   c            ╱   c                                     ⎥
# ⎢c⋅  ╱  ──────   -c⋅  ╱  ──────                                  ⎥
# ⎢  ╲╱   \omega      ╲╱   \omega                                  ⎥
# ⎢──────────────  ────────────────        0               0       ⎥
# ⎢    \omega           \omega                                     ⎥
# ⎢                                                                ⎥
# ⎢      0                0                -1              1       ⎥
# ⎢                                                                ⎥
# ⎢                                        ________        ________⎥
# ⎢                                       ╱   c           ╱   c    ⎥
# ⎢                                  c⋅  ╱  ──────   c⋅  ╱  ────── ⎥
# ⎢                                    ╲╱   \omega     ╲╱   \omega ⎥
# ⎢      0                0          ──────────────  ──────────────⎥
# ⎣                                      \omega          \omega    ⎦
